# %%
print ("Hello World")

# %%
a = 20
b = 250
c = a + b
print (a, " + ", b, " --> ", c)

# %%
a = "Shubh"
b = " Mittal"
c = a + b
print (a, " + ", b, " --> ", c)

# %%
a = "Shubh"
b = 100
c = a + str(b)
print (a, " + ", b, " --> ", c)

# %%
a = input("Enter First String: ")
b = input("Enter Second String: ")
c = a + b
print  (a, " + ", b, "      --> ", c)

# %%
a = int(input("Enter First No: "))
b = int(input("Enter Second No: "))
c = a + b
print (a, " + ", b, " --> ", c)

# %%
i=1
while i <= 10:
	print (i)
	i = i+1

  print ("range(20)        --> ", list(range(10)))
print ("range(15,20)     --> ", list(range(10,20)))
print ("range(0,20,2)    --> ", list(range(2,20,2)))
print ("range(-10,-20,2) --> ", list(range(-10,-20,2)))
print ("range(-10,-20,-2)--> ", list(range(-10,-20,-2)))

# %%
for i in range(2,10):
	print (i)

# %%
for i in range(5,20,2):
	print (i)

 for i in range(0,-10,-1):
	print (i)

# %%
for i in range(1,11):
	print (10," * ", i , " = ", i * 10)

# %%
a = int(input("Enter First No: "))
b = int(input("Enter Second No: "))
if  a > b:
	print (a," > ",b)
else:
	print (a," < ",b)

 n = int(input("Enter a No: "))
if  n % 2 == 0:
	print (n," is even")
else:
	print (n," is odd")
     n = int(input("Enter a No: "))
f=0
for i in range(2, n//2 + 1):
	if  n % i == 0:
		f=1
		break

if f==0:
	print ("Prime")
else:
	print ("Not Prime")

# %%
def Add(a,b):
	c=a+b
	return c

print ("Add(10,20) -->", Add(10,20))
print ("Add(20,50) -->", Add(20,50))
print ("Add(80,200) -->", Add(80,200))

def IsPrime(n):
	for i in range(2, n//2 + 1):
		if n%i==0:
			return 0
	return 1

print ("IsPrime(20)  --> ", IsPrime(20))
print ("IsPrime(23)  --> ", IsPrime(283))
print ("IsPrime(200) --> ", IsPrime(900))
print ("IsPrime(37)  --> ", IsPrime(377))
